# %%
# -*- coding: utf-8 -*-

from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import time
import csv
import sys
import tweepy
import json
import string
import codecs
import io

# %%
ckey = 'q6Fb34xVjsVMNka2Tw5HFBFsz'
csecret = 'Sg304dNVBi2aNEaC9kT2IolTdazYSEPfLMTz7KNzTZaejsXkgM'
atoken = '718614759000641536-dCdTQVPRxIH7mZR78OjGhhY6ddHT1tP'
asecret = 'fcmCqecjT6NvGgKdGhRql4XXFrpZbxv7myTObT8SFCD7X'

non_bmp_map = dict.fromkeys(range(0x10000, sys.maxunicode + 1), 0xfffd)

# %%
class StdOutListener(StreamListener):
    
    def on_data(self,data):
        
     try:
      
        all_data = json.loads(data)
        #id1 = all_data["id"]
        sname = unicode(all_data["user"]["name"])
        screen_name= unicode(all_data ["user"]["screen_name"])
        tweet = unicode(all_data["text"])
        followers = unicode(all_data["user"]["followers_count"])
        friends = unicode(all_data["user"]["friends_count"])
        status = unicode(all_data["user"]["statuses_count"])
        lists = unicode(all_data["user"]["listed_count"])
        favourites = unicode(all_data["user"]["favourites_count"])
        hashtags = unicode(all_data ["entities"]["hashtags"])
        urls = unicode(all_data ["entities"]["urls"])
        age = unicode(all_data["user"]["created_at"])
        source = unicode(all_data["source"])
        location = unicode(all_data["user"]["location"])
        description = unicode(all_data["user"]["description"])
        protected = unicode(all_data["user"]["protected"])
        verified = unicode(all_data["user"]["verified"])
        time_zone= unicode(all_data["user"]["time_zone"])
        geo= unicode(all_data["user"]["geo_enabled"])
        lang= unicode(all_data["user"]["lang"])
        created_at = unicode(all_data["created_at"])



        
        
        if int(followers)!=0:
         reputation = unicode((int(friends) / int(followers)))
        else :
         reputation= u"0"
         
        NoOfWords=unicode( len(tweet.split()))
        
        NoOfChars = unicode(len(tweet) - tweet.count(" "))
        
        NoOfChartsDes = unicode(len(description) - description.count(" "))
        
        NoOfWordsDes=unicode( len(description.split()))
        
        NoOfUrls = unicode(len(urls.split()))


        def counthashtags(lists):
         subs='#'
         global total
         total = 0
         MYlist = string.split(lists)
         for item in MYlist:
           if item.startswith(subs)== True:
            total += 1
         return total
        
        def count_input_character (input_str, character):
         return sum(w.startswith(character) for w in input_str.lower().split())
        
        NoOfTags=unicode( count_input_character (tweet, '#'))

        NoOfURLS1 = count_input_character (tweet,'https:')
        NoOfURLS2 = count_input_character (tweet,'www.')
        
        NoOfURLS = unicode(NoOfURLS1 + NoOfURLS2)
        
        #NoOfRetweet =unicode(count_input_character('RT'))
        #NoOfMention =unicode(count_input_character('@'))

        print sname
        print tweet
        print followers
        print friends
        print status
        print lists
        print favourites
        print reputation
        print NoOfWords
        print NoOfChars
        print NoOfTags
        print NoOfURLS
        print age
        print source
        print NoOfWordsDes
        print NoOfChartsDes

        non_bmp_map = dict.fromkeys(range(0x10000, sys.maxunicode + 1), 0xfffd)

        
        saveThis =(unicode(sname) + ',' + unicode(screen_name) + ',' + (tweet.translate(non_bmp_map)) + ',' + str(followers) + ',' + str(friends) +',' + str(status) +',' + str(lists) +',' + str(favourites) + ',' + str( reputation) + ', ' + str(NoOfWords) + ',' + str(NoOfChars) + ',' + str(NoOfTags) + ',' + str(NoOfURLS) + ',' + str(age) + ',' + unicode(source) + ',' + unicode(location) + ',' + unicode(description) + ',' + unicode(protected) + ',' + unicode(verified) + ',' + str(time_zone) + ',' + str(geo) + ',' + str(lang) + ',' + unicode(created_at) + ', ' + str(NoOfWordsDes) + ',' + str(NoOfChartsDes))

        saveFile = codecs.open("/home/niddal/Desktop/hashtag.csv",'a', "utf-8")
        
        saveFile.write(unicode(saveThis))
        saveFile.write('\n')
        saveFile.close()
                          
        return True
     except BaseException, e:
        print 'failed ondata,',str(e)
        time.sleep(5)

    def on_error(self,status):
        print status


auth = OAuthHandler(ckey,csecret)
auth.set_access_token(atoken,asecret)
twitterStream = Stream(auth, StdOutListener())

twitterStream.filter(track=[unicode("#hashtag", "utf-8")])
twitterStream.filter(languages=["ar"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1ede901919cc> in <module>()
#     112 twitterStream = Stream(auth, StdOutListener())
#     113
# --> 114 twitterStream.filter(track=[unicode("#hashtag", "utf-8")])
#     115 twitterStream.filter(languages=["ar"])
#
# /home/niddal/.local/lib/python2.7/site-packages/tweepy/streaming.pyc in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# /home/niddal/.local/lib/python2.7/site-packages/tweepy/streaming.pyc in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# /home/niddal/.local/lib/python2.7/site-packages/tweepy/streaming.pyc in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# /home/niddal/.local/lib/python2.7/site-packages/tweepy/streaming.pyc in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# /home/niddal/.local/lib/python2.7/site-packages/tweepy/streaming.pyc in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# /home/niddal/.local/lib/python2.7/site-packages/urllib3/response.pyc in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# /usr/lib/python2.7/httplib.pyc in read(self, amt)
#     585
#     586         if self.chunked:
# --> 587             return self._read_chunked(amt)
#     588
#     589         if amt is None:
#
# /usr/lib/python2.7/httplib.pyc in _read_chunked(self, amt)
#     627         while True:
#     628             if chunk_left is None:
# --> 629                 line = self.fp.readline(_MAXLINE + 1)
#     630                 if len(line) > _MAXLINE:
#     631                     raise LineTooLong("chunk size")
#
# /usr/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /usr/lib/python2.7/ssl.pyc in recv(self, buflen, flags)
#     752                     "non-zero flags not allowed in calls to recv() on %s" %
#     753                     self.__class__)
# --> 754             return self.read(buflen)
#     755         else:
#     756             return self._sock.recv(buflen, flags)
#
# /usr/lib/python2.7/ssl.pyc in read(self, len, buffer)
#     639                 v = self._sslobj.read(len, buffer)
#     640             else:
# --> 641                 v = self._sslobj.read(len)
#     642             return v
#     643         except SSLError as x:
#
# KeyboardInterrupt:
